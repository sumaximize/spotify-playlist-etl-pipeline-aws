# %%
import os
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# ##### Connect to the Spotify API

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=os.environ.get("spotify_client_id"), client_secret=os.environ.get("spotify_client_secret"))
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Top Songs - Global
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"
playlist_URI = playlist_link.split('/')[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %% [markdown]
# ##### Album DF

# %%
album_list = list()
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id, 'album_name':album_name, 'release_date':album_release_date, 'total_tracks':album_total_tracks, 'url':album_url}
    album_list.append(album_element)

# %% [markdown]
# _list of dictionaries_ elements: [{}, {}, ... {}]

# %%
album_list
# Out:
# [{'album_id': '1bBez9PNvkJPW08bU7NYta',
#   'album_name': 'Scarlet',
#   'release_date': '2023-09-20',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/1bBez9PNvkJPW08bU7NYta'},
#  {'album_id': '53985D8g3JcGBoULSOYYKX',
#   'album_name': 'Seven (feat. Latto)',
#   'release_date': '2023-07-14',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'},
#  {'album_id': '0fJ0beklzFwoBv01U8792s',
#   'album_name': '3D : The Remixes',
#   'release_date': '2023-10-02',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/0fJ0beklzFwoBv01U8792s'},
#  {'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'album_name': 'greedy',
#   'release_date': '2023-09-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'album_name': 'Lover',
#   'release_date': '2019-08-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '18ogtNq9F7DmMkNYO6Xb4k',
#   'album_name': 'Strangers',
#   'release_date': '2023-09-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/18ogtNq9F7DmMkNYO6Xb4k'},
#  {'album_id': '0FqAaUEyKCyUNFE1uQPZ7i',
#   'album_name': 'MAÑANA SERÁ BONITO (BICHOTA SEASON)',
#   'release_date': '2023-08-10',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/0FqAaUEyKCyUNFE1uQPZ7i'},
#  {'album_id': '3puAvurwvtvi1rodndIPW8',
#   'album_name': 'LA VIDA ES UNA',
#   'release_date': '2023-03-23',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/3puAvurwvtvi1rodndIPW8'},
#  {'album_id': '72GhGik5fsSeFkgpjsllVj',
#   'album_name': 'UN PREVIEW',
#   'release_date': '2023-09-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/72GhGik5fsSeFkgpjsllVj'},
#  {'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'album_name': 'GUTS',
#   'release_date': '2023-09-08',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'},
#  {'album_id': '66k6EGkPtYoN44anGIsEPW',
#   'album_name': 'Si No Estás',
#   'release_date': '2022-09-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/66k6EGkPtYoN44anGIsEPW'},
#  {'album_id': '5qmZefgh78fN3jsyPPlvuw',
#   'album_name': 'a Gift & a Curse',
#   'release_date': '2023-06-16',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/5qmZefgh78fN3jsyPPlvuw'},
#  {'album_id': '07kam1Dks7GIucbSelfvyX',
#   'album_name': 'Columbia',
#   'release_date': '2023-07-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/07kam1Dks7GIucbSelfvyX'},
#  {'album_id': '4jox3ip1I39DFC2B7R5qLH',
#   'album_name': 'GÉNESIS',
#   'release_date': '2023-06-29',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4jox3ip1I39DFC2B7R5qLH'},
#  {'album_id': '3AafSrFIbJPH6BJHiJm1Cd',
#   'album_name': 'What Was I Made For? [From The Motion Picture "Barbie"]',
#   'release_date': '2023-07-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3AafSrFIbJPH6BJHiJm1Cd'},
#  {'album_id': '78bpIziExqiI9qztvNFlQu',
#   'album_name': 'AM',
#   'release_date': '2013-09-09',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#  {'album_id': '5cH7FqB7JD5q1tJXJ7FHYu',
#   'album_name': 'Dance The Night (From Barbie The Album)',
#   'release_date': '2023-05-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5cH7FqB7JD5q1tJXJ7FHYu'},
#  {'album_id': '6NcI39WPu4kY6Tul11nhSv',
#   'album_name': 'Daylight',
#   'release_date': '2023-04-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6NcI39WPu4kY6Tul11nhSv'},
#  {'album_id': '5MU0RmBSpoSxOPYBfcobDc',
#   'album_name': 'Prada',
#   'release_date': '2023-08-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5MU0RmBSpoSxOPYBfcobDc'},
#  {'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'album_name': "Harry's House",
#   'release_date': '2022-05-20',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#  {'album_id': '4x6cjOcVz44aiLSOHCLKPd',
#   'album_name': 'Que Onda',
#   'release_date': '2023-08-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4x6cjOcVz44aiLSOHCLKPd'},
#  {'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'album_name': 'Starboy',
#   'release_date': '2016-11-25',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#  {'album_id': '3Fk8yQvPlCHgwR2pNhEIRA',
#   'album_name': 'Don Juan',
#   'release_date': '2023-08-25',
#   'total_tracks': 25,
#   'url': 'https://open.spotify.com/album/3Fk8yQvPlCHgwR2pNhEIRA'},
#  {'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'album_name': 'SOS',
#   'release_date': '2022-12-08',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'},
#  {'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'album_name': 'GUTS',
#   'release_date': '2023-09-08',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'},
#  {'album_id': '3WLJmMZUeDOuERFAk1Mxs6',
#   'album_name': 'Jawan',
#   'release_date': '2023-09-05',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/3WLJmMZUeDOuERFAk1Mxs6'},
#  {'album_id': '52PtAAvfi8ZGTRK5c700y4',
#   'album_name': 'Colmillo De Leche',
#   'release_date': '2023-05-19',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/52PtAAvfi8ZGTRK5c700y4'},
#  {'album_id': '6PbnGueEO6LGodPfvNldYf',
#   'album_name': 'Zach Bryan',
#   'release_date': '2023-08-25',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/6PbnGueEO6LGodPfvNldYf'},
#  {'album_id': '2Cn1d2KgbkAqbZCJ1RzdkA',
#   'album_name': 'The Land Is Inhospitable and So Are We',
#   'release_date': '2023-09-15',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/2Cn1d2KgbkAqbZCJ1RzdkA'},
#  {'album_id': '2QJmrSgbdM35R67eoGQo4j',
#   'album_name': '1989',
#   'release_date': '2014-10-27',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/2QJmrSgbdM35R67eoGQo4j'},
#  {'album_id': '7ixOAT89NSsgUITYc5ByB5',
#   'album_name': 'Layover',
#   'release_date': '2023-09-08',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/7ixOAT89NSsgUITYc5ByB5'},
#  {'album_id': '4jtQUtS4ABgER3DnGfKJCv',
#   'album_name': 'Classy 101',
#   'release_date': '2023-03-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4jtQUtS4ABgER3DnGfKJCv'},
#  {'album_id': '5l0QlaI3wdZpE7ggoO5Rwg',
#   'album_name': 'Sprinter',
#   'release_date': '2023-06-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5l0QlaI3wdZpE7ggoO5Rwg'},
#  {'album_id': '2QJmrSgbdM35R67eoGQo4j',
#   'album_name': '1989',
#   'release_date': '2014-10-27',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/2QJmrSgbdM35R67eoGQo4j'},
#  {'album_id': '4AdZV63ycxFLF6Hcol0QnB',
#   'album_name': 'Starboy',
#   'release_date': '2016-11-24',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/4AdZV63ycxFLF6Hcol0QnB'},
#  {'album_id': '42D6fdFJ4SLnh4jXZJrsNa',
#   'album_name': 'Holanda',
#   'release_date': '2023-07-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/42D6fdFJ4SLnh4jXZJrsNa'},
#  {'album_id': '4xkM0BwLM9H2IUcbYzpcBI',
#   'album_name': 'I Love You.',
#   'release_date': '2013-04-19',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4xkM0BwLM9H2IUcbYzpcBI'},
#  {'album_id': '0Gf1yE895FKK4YWVRuAeg8',
#   'album_name': 'Long Way Down (Deluxe)',
#   'release_date': '2013-06-24',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/0Gf1yE895FKK4YWVRuAeg8'},
#  {'album_id': '5O0zUvdnJr0RbWzLFneN2i',
#   'album_name': 'Popular (Music from the HBO Original Series)',
#   'release_date': '2023-06-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5O0zUvdnJr0RbWzLFneN2i'},
#  {'album_id': '5DvJgsMLbaR1HmAI6VhfcQ',
#   'album_name': 'Endless Summer Vacation',
#   'release_date': '2023-08-18',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/5DvJgsMLbaR1HmAI6VhfcQ'},
#  {'album_id': '5V729UqvhwNOcMejx0m55I',
#   'album_name': "NewJeans 'Super Shy'",
#   'release_date': '2023-07-07',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/5V729UqvhwNOcMejx0m55I'},
#  {'album_id': '5i9lMMUZ1QZNsLEE3j50kT',
#   'album_name': 'El Comienzo',
#   'release_date': '2023-08-25',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/5i9lMMUZ1QZNsLEE3j50kT'},
#  {'album_id': '151w1FgRZfnKZA9FEcg9Z3',
#   'album_name': 'Midnights',
#   'release_date': '2022-10-21',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/151w1FgRZfnKZA9FEcg9Z3'},
#  {'album_id': '5aDEezKnOqyQo0qvTFhpkM',
#   'album_name': 'DESVELADO',
#   'release_date': '2023-04-28',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM'},
#  {'album_id': '07w0rG5TETcyihsEIZR3qG',
#   'album_name': 'SOS',
#   'release_date': '2022-12-09',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/07w0rG5TETcyihsEIZR3qG'},
#  {'album_id': '18NOKLkZETa4sWwLMIm0UZ',
#   'album_name': 'UTOPIA',
#   'release_date': '2023-07-28',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/18NOKLkZETa4sWwLMIm0UZ'},
#  {'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'album_name': 'GUTS',
#   'release_date': '2023-09-08',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'},
#  {'album_id': '22sXXkKgjEuawIFL1e1tRw',
#   'album_name': 'Water',
#   'release_date': '2023-07-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/22sXXkKgjEuawIFL1e1tRw'},
#  {'album_id': '1wt2WZBZZ9GhM0AC61l7SS',
#   'album_name': 'Heeriye (feat. Arijit Singh)',
#   'release_date': '2023-07-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1wt2WZBZZ9GhM0AC61l7SS'},
#  {'album_id': '0nayxjaX54Frd7GsZq6Pbs',
#   'album_name': 'Rave & Roses Ultra',
#   'release_date': '2023-04-27',
#   'total_tracks': 22,
#   'url': 'https://open.spotify.com/album/0nayxjaX54Frd7GsZq6Pbs'}]

# %%
album_df = pd.DataFrame.from_dict(album_list)
album_df.head()
# Out:
#                  album_id           album_name release_date  total_tracks  \
# 0  1bBez9PNvkJPW08bU7NYta              Scarlet   2023-09-20            15
# 1  53985D8g3JcGBoULSOYYKX  Seven (feat. Latto)   2023-07-14             3
# 2  0fJ0beklzFwoBv01U8792s     3D : The Remixes   2023-10-02             7
# 3  3UOV8XvCwMKaATRNXrYCjN               greedy   2023-09-15             1
# 4  1NAmidJlEaVgA3MpcPFYGq                Lover   2019-08-23            18
#
#                                                  url
# 0  https://open.spotify.com/album/1bBez9PNvkJPW08...
# 1  https://open.spotify.com/album/53985D8g3JcGBoU...
# 2  https://open.spotify.com/album/0fJ0beklzFwoBv0...
# 3  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 4  https://open.spotify.com/album/1NAmidJlEaVgA3M...

# %%
album_df.shape
# Out:
# (50, 5)

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   album_name    50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %% [markdown]
# `album_id`: is PK
#
# `release_date`: should be `datetime`

# %%
album_df.drop_duplicates(subset=['album_id'], inplace=True)

# %% [markdown]
# ##### Artist DF

# %% [markdown]
# List of key-value tuples
#
# `dict_var.items() --> [(key1, value1), ()...]`

# %%
artist_list = list()
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['album']['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'artist_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df.drop_duplicates(subset=['artist_id'], inplace=True)
artist_df.shape
# Out:
# (52, 3)

# %%
artist_df.head()
# Out:
#                 artist_id  artist_name  \
# 0  5cj0lLjcoR7YOSnhnX0Po5     Doja Cat
# 1  6HaGTQPmzraVmaVxvz6EUc    Jung Kook
# 2  3MdXrJWsbVzdn6fe5JYkSQ        Latto
# 4  2LIk90788K0zvyj2JJVwkJ  Jack Harlow
# 5  45dkTj5sMRSjrmBSBeiHym   Tate McRae
#
#                                           artist_url
# 0  https://api.spotify.com/v1/artists/5cj0lLjcoR7...
# 1  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 2  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 4  https://api.spotify.com/v1/artists/2LIk90788K0...
# 5  https://api.spotify.com/v1/artists/45dkTj5sMRS...

# %% [markdown]
# ##### Song DF

# %%
song_list = list()
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['artists'][0]['id']
    song_element = {'song_id': song_id, 'song_name':song_name, 'song_duration':song_duration, 'song_url':song_url, 'song_popularity':song_popularity, 'song_added':song_added, 'album_id':album_id, 'artist_id':artist_id  }

    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '56y1jOTK0XSvJzVv9vHQBK',
#   'song_name': 'Paint The Town Red',
#   'song_duration': 230480,
#   'song_url': 'https://open.spotify.com/track/56y1jOTK0XSvJzVv9vHQBK',
#   'song_popularity': 85,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '1bBez9PNvkJPW08bU7NYta',
#   'artist_id': '5cj0lLjcoR7YOSnhnX0Po5'},
#  {'song_id': '7x9aauaA9cu6tyfpHnqDLo',
#   'song_name': 'Seven (feat. Latto) (Explicit Ver.)',
#   'song_duration': 184400,
#   'song_url': 'https://open.spotify.com/track/7x9aauaA9cu6tyfpHnqDLo',
#   'song_popularity': 97,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '53985D8g3JcGBoULSOYYKX',
#   'artist_id': '6HaGTQPmzraVmaVxvz6EUc'},
#  {'song_id': '01qFKNWq73UfEslI0GvumE',
#   'song_name': '3D (feat. Jack Harlow)',
#   'song_duration': 201812,
#   'song_url': 'https://open.spotify.com/track/01qFKNWq73UfEslI0GvumE',
#   'song_popularity': 84,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '0fJ0beklzFwoBv01U8792s',
#   'artist_id': '6HaGTQPmzraVmaVxvz6EUc'},
#  {'song_id': '3rUGC1vUpkDG9CZFHMur1t',
#   'song_name': 'greedy',
#   'song_duration': 131872,
#   'song_url': 'https://open.spotify.com/track/3rUGC1vUpkDG9CZFHMur1t',
#   'song_popularity': 96,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'artist_id': '45dkTj5sMRSjrmBSBeiHym'},
#  {'song_id': '1BxfuPKGuaTgP7aM0Bbdwr',
#   'song_name': 'Cruel Summer',
#   'song_duration': 178426,
#   'song_url': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr',
#   'song_popularity': 99,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '5mjYQaktjmjcMKcUIcqz4s',
#   'song_name': 'Strangers',
#   'song_duration': 172964,
#   'song_url': 'https://open.spotify.com/track/5mjYQaktjmjcMKcUIcqz4s',
#   'song_popularity': 96,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '18ogtNq9F7DmMkNYO6Xb4k',
#   'artist_id': '7uMDnSZyUYNBPLhPMNuaM2'},
#  {'song_id': '5RqSsdzTNPX1uzkmlHCFvK',
#   'song_name': 'QLONA',
#   'song_duration': 172797,
#   'song_url': 'https://open.spotify.com/track/5RqSsdzTNPX1uzkmlHCFvK',
#   'song_popularity': 93,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '0FqAaUEyKCyUNFE1uQPZ7i',
#   'artist_id': '790FomKkXshlbRYZFtlgla'},
#  {'song_id': '7ABLbnD53cQK00mhcaOUVG',
#   'song_name': 'LALA',
#   'song_duration': 197920,
#   'song_url': 'https://open.spotify.com/track/7ABLbnD53cQK00mhcaOUVG',
#   'song_popularity': 97,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '3puAvurwvtvi1rodndIPW8',
#   'artist_id': '7iK8PXO48WeuP03g8YR51W'},
#  {'song_id': '63ui2w3QJBp8xx0c1MJB2Z',
#   'song_name': 'UN PREVIEW',
#   'song_duration': 165582,
#   'song_url': 'https://open.spotify.com/track/63ui2w3QJBp8xx0c1MJB2Z',
#   'song_popularity': 92,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '72GhGik5fsSeFkgpjsllVj',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '1kuGVB7EU95pJObxwvfwKS',
#   'song_name': 'vampire',
#   'song_duration': 219724,
#   'song_url': 'https://open.spotify.com/track/1kuGVB7EU95pJObxwvfwKS',
#   'song_popularity': 95,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '2HafqoJbgXdtjwCOvNEF14',
#   'song_name': 'Si No Estás',
#   'song_duration': 184061,
#   'song_url': 'https://open.spotify.com/track/2HafqoJbgXdtjwCOvNEF14',
#   'song_popularity': 91,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '66k6EGkPtYoN44anGIsEPW',
#   'artist_id': '0jbo7KFNMiIkfBR6ih0yhm'},
#  {'song_id': '4rXLjWdF2ZZpXCVTfWcshS',
#   'song_name': 'fukumean',
#   'song_duration': 125040,
#   'song_url': 'https://open.spotify.com/track/4rXLjWdF2ZZpXCVTfWcshS',
#   'song_popularity': 95,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '5qmZefgh78fN3jsyPPlvuw',
#   'artist_id': '2hlmm7s2ICUX0LVIhVFlZQ'},
#  {'song_id': '6XbtvPmIpyCbjuT0e8cQtp',
#   'song_name': 'Columbia',
#   'song_duration': 186000,
#   'song_url': 'https://open.spotify.com/track/6XbtvPmIpyCbjuT0e8cQtp',
#   'song_popularity': 96,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '07kam1Dks7GIucbSelfvyX',
#   'artist_id': '52iwsT98xCoGgiGntTiR7K'},
#  {'song_id': '7mXuWTczZNxG5EDcjFEuJR',
#   'song_name': 'LADY GAGA',
#   'song_duration': 212878,
#   'song_url': 'https://open.spotify.com/track/7mXuWTczZNxG5EDcjFEuJR',
#   'song_popularity': 95,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '4jox3ip1I39DFC2B7R5qLH',
#   'artist_id': '12GqGscKJx3aE4t07u7eVZ'},
#  {'song_id': '6wf7Yu7cxBSPrRlWeSeK0Q',
#   'song_name': 'What Was I Made For? [From The Motion Picture "Barbie"]',
#   'song_duration': 222369,
#   'song_url': 'https://open.spotify.com/track/6wf7Yu7cxBSPrRlWeSeK0Q',
#   'song_popularity': 96,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '3AafSrFIbJPH6BJHiJm1Cd',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '5XeFesFbtLpXzIVDNQP22n',
#   'song_name': 'I Wanna Be Yours',
#   'song_duration': 183956,
#   'song_url': 'https://open.spotify.com/track/5XeFesFbtLpXzIVDNQP22n',
#   'song_popularity': 94,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '78bpIziExqiI9qztvNFlQu',
#   'artist_id': '7Ln80lUS6He07XvHI8qqHH'},
#  {'song_id': '1vYXt7VSjH9JIM5oRRo7vA',
#   'song_name': 'Dance The Night - From Barbie The Album',
#   'song_duration': 176579,
#   'song_url': 'https://open.spotify.com/track/1vYXt7VSjH9JIM5oRRo7vA',
#   'song_popularity': 95,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '5cH7FqB7JD5q1tJXJ7FHYu',
#   'artist_id': '6M2wZ9GZgrQXHCFfjv46we'},
#  {'song_id': '1odExI7RdWc4BT515LTAwj',
#   'song_name': 'Daylight',
#   'song_duration': 212953,
#   'song_url': 'https://open.spotify.com/track/1odExI7RdWc4BT515LTAwj',
#   'song_popularity': 95,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '6NcI39WPu4kY6Tul11nhSv',
#   'artist_id': '33NVpKoXjItPwUJTMZIOiY'},
#  {'song_id': '59NraMJsLaMCVtwXTSia8i',
#   'song_name': 'Prada',
#   'song_duration': 132359,
#   'song_url': 'https://open.spotify.com/track/59NraMJsLaMCVtwXTSia8i',
#   'song_popularity': 93,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '5MU0RmBSpoSxOPYBfcobDc',
#   'artist_id': '5wCmhq5J2hPwL2r0eKurxn'},
#  {'song_id': '4Dvkj6JhhA12EX05fT7y2e',
#   'song_name': 'As It Was',
#   'song_duration': 167303,
#   'song_url': 'https://open.spotify.com/track/4Dvkj6JhhA12EX05fT7y2e',
#   'song_popularity': 94,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'artist_id': '6KImCVD70vtIoJWnq6nGn3'},
#  {'song_id': '6uIIdjYTxxpWOyWuVXrKQO',
#   'song_name': 'Que Onda',
#   'song_duration': 191466,
#   'song_url': 'https://open.spotify.com/track/6uIIdjYTxxpWOyWuVXrKQO',
#   'song_popularity': 92,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '4x6cjOcVz44aiLSOHCLKPd',
#   'artist_id': '6dLuQ5qXxIuWc5urxfIiZR'},
#  {'song_id': '7MXVkk9YMctZqd1Srtv4MB',
#   'song_name': 'Starboy',
#   'song_duration': 230453,
#   'song_url': 'https://open.spotify.com/track/7MXVkk9YMctZqd1Srtv4MB',
#   'song_popularity': 93,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '4bw8mcDUSRWfQo63ZTYRnU',
#   'song_name': 'Según Quién',
#   'song_duration': 142334,
#   'song_url': 'https://open.spotify.com/track/4bw8mcDUSRWfQo63ZTYRnU',
#   'song_popularity': 85,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '3Fk8yQvPlCHgwR2pNhEIRA',
#   'artist_id': '1r4hJ1h58CWwUQe3MxPuau'},
#  {'song_id': '1Qrg8KqiBpW07V7PNxwwwL',
#   'song_name': 'Kill Bill',
#   'song_duration': 153946,
#   'song_url': 'https://open.spotify.com/track/1Qrg8KqiBpW07V7PNxwwwL',
#   'song_popularity': 91,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP'},
#  {'song_id': '3IX0yuEVvDbnqUwMBB3ouC',
#   'song_name': 'bad idea right?',
#   'song_duration': 184783,
#   'song_url': 'https://open.spotify.com/track/3IX0yuEVvDbnqUwMBB3ouC',
#   'song_popularity': 93,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '3xMHXmedL5Rvfxmiar9Ryv',
#   'song_name': 'Chaleya',
#   'song_duration': 200373,
#   'song_url': 'https://open.spotify.com/track/3xMHXmedL5Rvfxmiar9Ryv',
#   'song_popularity': 83,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '3WLJmMZUeDOuERFAk1Mxs6',
#   'artist_id': '4zCH9qm4R2DADamUHMCa6O'},
#  {'song_id': '25OeKzcqakFPaJlXHPE5lm',
#   'song_name': 'Primera Cita',
#   'song_duration': 186455,
#   'song_url': 'https://open.spotify.com/track/25OeKzcqakFPaJlXHPE5lm',
#   'song_popularity': 87,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '52PtAAvfi8ZGTRK5c700y4',
#   'artist_id': '66ihevNkSYNzRAl44dx6jJ'},
#  {'song_id': '4KULAymBBJcPRpk1yO4dOG',
#   'song_name': 'I Remember Everything (feat. Kacey Musgraves)',
#   'song_duration': 227195,
#   'song_url': 'https://open.spotify.com/track/4KULAymBBJcPRpk1yO4dOG',
#   'song_popularity': 93,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '6PbnGueEO6LGodPfvNldYf',
#   'artist_id': '40ZNYROS4zLfyyBSs2PGe2'},
#  {'song_id': '3vkCueOmm7xQDoJ17W1Pm3',
#   'song_name': 'My Love Mine All Mine',
#   'song_duration': 137773,
#   'song_url': 'https://open.spotify.com/track/3vkCueOmm7xQDoJ17W1Pm3',
#   'song_popularity': 91,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '2Cn1d2KgbkAqbZCJ1RzdkA',
#   'artist_id': '2uYWxilOVlUdk4oV9DvwqK'},
#  {'song_id': '1p80LdxRV74UKvL8gnD7ky',
#   'song_name': 'Blank Space',
#   'song_duration': 231826,
#   'song_url': 'https://open.spotify.com/track/1p80LdxRV74UKvL8gnD7ky',
#   'song_popularity': 82,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '2QJmrSgbdM35R67eoGQo4j',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '5h1BN75CEh8wdSwE1xrbSe',
#   'song_name': 'Slow Dancing',
#   'song_duration': 187026,
#   'song_url': 'https://open.spotify.com/track/5h1BN75CEh8wdSwE1xrbSe',
#   'song_popularity': 95,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '7ixOAT89NSsgUITYc5ByB5',
#   'artist_id': '3JsHnjpbhX4SnySpvpa9DK'},
#  {'song_id': '6XSqqQIy7Lm7SnwxS4NrGx',
#   'song_name': 'Classy 101',
#   'song_duration': 195986,
#   'song_url': 'https://open.spotify.com/track/6XSqqQIy7Lm7SnwxS4NrGx',
#   'song_popularity': 93,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '4jtQUtS4ABgER3DnGfKJCv',
#   'artist_id': '2LRoIwlKmHjgvigdNGBHNo'},
#  {'song_id': '2FDTHlrBguDzQkp7PVj16Q',
#   'song_name': 'Sprinter',
#   'song_duration': 229133,
#   'song_url': 'https://open.spotify.com/track/2FDTHlrBguDzQkp7PVj16Q',
#   'song_popularity': 94,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '5l0QlaI3wdZpE7ggoO5Rwg',
#   'artist_id': '6Ip8FS7vWT1uKkJSweANQK'},
#  {'song_id': '4lIxdJw6W3Fg4vUIYCB0S5',
#   'song_name': 'Style',
#   'song_duration': 231000,
#   'song_url': 'https://open.spotify.com/track/4lIxdJw6W3Fg4vUIYCB0S5',
#   'song_popularity': 82,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '2QJmrSgbdM35R67eoGQo4j',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '2LBqCSwhJGcFQeTHMVGwy3',
#   'song_name': 'Die For You',
#   'song_duration': 260253,
#   'song_url': 'https://open.spotify.com/track/2LBqCSwhJGcFQeTHMVGwy3',
#   'song_popularity': 90,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '4AdZV63ycxFLF6Hcol0QnB',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '6irysuQyZWd7Bjj7ePiOs2',
#   'song_name': 'Holanda',
#   'song_duration': 231693,
#   'song_url': 'https://open.spotify.com/track/6irysuQyZWd7Bjj7ePiOs2',
#   'song_popularity': 92,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '42D6fdFJ4SLnh4jXZJrsNa',
#   'artist_id': '6nVcHLIgY5pE2YCl8ubca1'},
#  {'song_id': '2QjOHCTQ1Jl3zawyYOpxh6',
#   'song_name': 'Sweater Weather',
#   'song_duration': 240400,
#   'song_url': 'https://open.spotify.com/track/2QjOHCTQ1Jl3zawyYOpxh6',
#   'song_popularity': 92,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '4xkM0BwLM9H2IUcbYzpcBI',
#   'artist_id': '77SW9BnxLY8rJ0RciFqkHh'},
#  {'song_id': '3JvKfv6T31zO0ini8iNItO',
#   'song_name': 'Another Love',
#   'song_duration': 244360,
#   'song_url': 'https://open.spotify.com/track/3JvKfv6T31zO0ini8iNItO',
#   'song_popularity': 91,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '0Gf1yE895FKK4YWVRuAeg8',
#   'artist_id': '2txHhyCwHjUEpJjWrEyqyX'},
#  {'song_id': '6WzRpISELf3YglGAh7TXcG',
#   'song_name': 'Popular (with Playboi Carti & Madonna) - Music from the HBO Original Series',
#   'song_duration': 215466,
#   'song_url': 'https://open.spotify.com/track/6WzRpISELf3YglGAh7TXcG',
#   'song_popularity': 93,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '5O0zUvdnJr0RbWzLFneN2i',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '7DSAEUvxU8FajXtRloy8M0',
#   'song_name': 'Flowers',
#   'song_duration': 200600,
#   'song_url': 'https://open.spotify.com/track/7DSAEUvxU8FajXtRloy8M0',
#   'song_popularity': 87,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '5DvJgsMLbaR1HmAI6VhfcQ',
#   'artist_id': '5YGY8feqx7naU7z4HrwZM6'},
#  {'song_id': '5sdQOyqq2IDhvmx2lHOpwd',
#   'song_name': 'Super Shy',
#   'song_duration': 154666,
#   'song_url': 'https://open.spotify.com/track/5sdQOyqq2IDhvmx2lHOpwd',
#   'song_popularity': 92,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '5V729UqvhwNOcMejx0m55I',
#   'artist_id': '6HvZYsbFfjnjFrWF950C9d'},
#  {'song_id': '2yzshFeBIwH8tWIqHEFLeD',
#   'song_name': 'un x100to',
#   'song_duration': 194563,
#   'song_url': 'https://open.spotify.com/track/2yzshFeBIwH8tWIqHEFLeD',
#   'song_popularity': 85,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '5i9lMMUZ1QZNsLEE3j50kT',
#   'artist_id': '6XkjpgcEsYab502Vr1bBeW'},
#  {'song_id': '0V3wPSX9ygBnCm8psDIegu',
#   'song_name': 'Anti-Hero',
#   'song_duration': 200690,
#   'song_url': 'https://open.spotify.com/track/0V3wPSX9ygBnCm8psDIegu',
#   'song_popularity': 92,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '151w1FgRZfnKZA9FEcg9Z3',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '3qQbCzHBycnDpGskqOWY0E',
#   'song_name': 'Ella Baila Sola',
#   'song_duration': 165671,
#   'song_url': 'https://open.spotify.com/track/3qQbCzHBycnDpGskqOWY0E',
#   'song_popularity': 86,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '5aDEezKnOqyQo0qvTFhpkM',
#   'artist_id': '0XeEobZplHxzM9QzFQWLiR'},
#  {'song_id': '4iZ4pt7kvcaH6Yo8UoZ4s2',
#   'song_name': 'Snooze',
#   'song_duration': 201800,
#   'song_url': 'https://open.spotify.com/track/4iZ4pt7kvcaH6Yo8UoZ4s2',
#   'song_popularity': 92,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '07w0rG5TETcyihsEIZR3qG',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP'},
#  {'song_id': '6wsqVwoiVH2kde4k4KKAFU',
#   'song_name': 'I KNOW ?',
#   'song_duration': 211582,
#   'song_url': 'https://open.spotify.com/track/6wsqVwoiVH2kde4k4KKAFU',
#   'song_popularity': 92,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '18NOKLkZETa4sWwLMIm0UZ',
#   'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'song_id': '2gyxAWHebV7xPYVxqoi86f',
#   'song_name': 'get him back!',
#   'song_duration': 211141,
#   'song_url': 'https://open.spotify.com/track/2gyxAWHebV7xPYVxqoi86f',
#   'song_popularity': 92,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '5aIVCx5tnk0ntmdiinnYvw',
#   'song_name': 'Water',
#   'song_duration': 200255,
#   'song_url': 'https://open.spotify.com/track/5aIVCx5tnk0ntmdiinnYvw',
#   'song_popularity': 89,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '22sXXkKgjEuawIFL1e1tRw',
#   'artist_id': '3SozjO3Lat463tQICI9LcE'},
#  {'song_id': '5PUXKVVVQ74C3gl5vKy9Li',
#   'song_name': 'Heeriye (feat. Arijit Singh)',
#   'song_duration': 194857,
#   'song_url': 'https://open.spotify.com/track/5PUXKVVVQ74C3gl5vKy9Li',
#   'song_popularity': 90,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '1wt2WZBZZ9GhM0AC61l7SS',
#   'artist_id': '74OaRjmyh0XyRZsQQQ5l7c'},
#  {'song_id': '1s7oOCT8vauUh01PbJD6ps',
#   'song_name': 'Calm Down (with Selena Gomez)',
#   'song_duration': 239317,
#   'song_url': 'https://open.spotify.com/track/1s7oOCT8vauUh01PbJD6ps',
#   'song_popularity': 80,
#   'song_added': '2023-10-06T10:09:15Z',
#   'album_id': '0nayxjaX54Frd7GsZq6Pbs',
#   'artist_id': '46pWGuE3dSwY3bMMXGBvVS'}]

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df.head()
# Out:
#                   song_id                            song_name  song_duration  \
# 0  56y1jOTK0XSvJzVv9vHQBK                   Paint The Town Red         230480
# 1  7x9aauaA9cu6tyfpHnqDLo  Seven (feat. Latto) (Explicit Ver.)         184400
# 2  01qFKNWq73UfEslI0GvumE               3D (feat. Jack Harlow)         201812
# 3  3rUGC1vUpkDG9CZFHMur1t                               greedy         131872
# 4  1BxfuPKGuaTgP7aM0Bbdwr                         Cruel Summer         178426
#
#                                             song_url  song_popularity  \
# 0  https://open.spotify.com/track/56y1jOTK0XSvJzV...               85
# 1  https://open.spotify.com/track/7x9aauaA9cu6tyf...               97
# 2  https://open.spotify.com/track/01qFKNWq73UfEsl...               84
# 3  https://open.spotify.com/track/3rUGC1vUpkDG9CZ...               96
# 4  https://open.spotify.com/track/1BxfuPKGuaTgP7a...               99
#
#              song_added                album_id               artist_id
# 0  2023-10-06T10:09:15Z  1bBez9PNvkJPW08bU7NYta  5cj0lLjcoR7YOSnhnX0Po5
# 1  2023-10-06T10:09:15Z  53985D8g3JcGBoULSOYYKX  6HaGTQPmzraVmaVxvz6EUc
# 2  2023-10-06T10:09:15Z  0fJ0beklzFwoBv01U8792s  6HaGTQPmzraVmaVxvz6EUc
# 3  2023-10-06T10:09:15Z  3UOV8XvCwMKaATRNXrYCjN  45dkTj5sMRSjrmBSBeiHym
# 4  2023-10-06T10:09:15Z  1NAmidJlEaVgA3MpcPFYGq  06HL4z0CvFAxyc27GXpf02

# %%
song_df.drop_duplicates(subset=['song_id'], inplace=True)

# %% [markdown]
# Convert columns to type _datetime_

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])
